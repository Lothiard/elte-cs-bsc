# %%
import pandas as pd
import numpy as np

# %%
data = {
    "city": [
        "Budapest", "Debrecen", "Szeged", "Pécs", "Győr", 
        "Miskolc", "Nyíregyháza", "Kecskemét", "Székesfehérvár", 
        "Eger", "Veszprém", "Tatabánya", "Salgótarján", "Kaposvár"
    ],
    "latitude": [
        47.4979, 47.5316, 46.253, 46.0727, 47.6875, 
        48.1031, 47.9495, 46.8964, 47.186, 
        47.9025, 47.0928, 47.5883, 48.1042, 46.3597
    ],
    "longitude": [
        19.0402, 21.6273, 20.1414, 18.2323, 17.6504, 
        20.7784, 21.7247, 19.6897, 18.4221, 
        20.3772, 17.9093, 18.3973, 19.8033, 17.7952
    ],
    "population": [
        1752286, 202402, 160766, 145347, 131267, 
        151025, 119746, 110687, 96170, 
        53696, 58763, 66124, 32133, 60300
    ],
    "area": [
        525, 461, 280, 162, 174, 
        236, 274, 321, 170, 
        92, 126, 91, 102, 113
    ]
}

# DataFrame létrehozása
df = pd.DataFrame(data)

# CSV mentése
df.to_csv("cities.csv", index=False)

print("Az adatfájl létrejött: 'cities.csv'")
# Out:
# Az adatfájl létrejött: 'cities.csv'

# %%
df = pd.read_csv("cities.csv")

#print(df.head())
#print(df.info())
print(df["city"].nunique())
print(df)
# Out:
# 14
#               city  latitude  longitude  population  area
# 0         Budapest   47.4979    19.0402     1752286   525
# 1         Debrecen   47.5316    21.6273      202402   461
# 2           Szeged   46.2530    20.1414      160766   280
# 3             Pécs   46.0727    18.2323      145347   162
# 4             Győr   47.6875    17.6504      131267   174
# 5          Miskolc   48.1031    20.7784      151025   236
# 6      Nyíregyháza   47.9495    21.7247      119746   274
# 7        Kecskemét   46.8964    19.6897      110687   321
# 8   Székesfehérvár   47.1860    18.4221       96170   170
# 9             Eger   47.9025    20.3772       53696    92
# 10        Veszprém   47.0928    17.9093       58763   126
# 11       Tatabánya   47.5883    18.3973       66124    91
# 12     Salgótarján   48.1042    19.8033       32133   102
# 13        Kaposvár   46.3597    17.7952       60300   113

# %%
filtered_df = df[df["population"] > 100000] 
print(filtered_df)
avg_population = filtered_df["population"].mean()
print(avg_population)
# Out:
#           city  latitude  longitude  population  area
# 0     Budapest   47.4979    19.0402     1752286   525
# 1     Debrecen   47.5316    21.6273      202402   461
# 2       Szeged   46.2530    20.1414      160766   280
# 3         Pécs   46.0727    18.2323      145347   162
# 4         Győr   47.6875    17.6504      131267   174
# 5      Miskolc   48.1031    20.7784      151025   236
# 6  Nyíregyháza   47.9495    21.7247      119746   274
# 7    Kecskemét   46.8964    19.6897      110687   321
# 346690.75

# %%
print(df.isnull().sum())
# Out:
# city          0
# latitude      0
# longitude     0
# population    0
# area          0
# dtype: int64

# %%
df["pop_density"] = df["population"] / df["area"]

print(df)
# Out:
#               city  latitude  longitude  population  area  pop_density
# 0         Budapest   47.4979    19.0402     1752286   525  3337.687619
# 1         Debrecen   47.5316    21.6273      202402   461   439.049892
# 2           Szeged   46.2530    20.1414      160766   280   574.164286
# 3             Pécs   46.0727    18.2323      145347   162   897.203704
# 4             Győr   47.6875    17.6504      131267   174   754.408046
# 5          Miskolc   48.1031    20.7784      151025   236   639.936441
# 6      Nyíregyháza   47.9495    21.7247      119746   274   437.029197
# 7        Kecskemét   46.8964    19.6897      110687   321   344.819315
# 8   Székesfehérvár   47.1860    18.4221       96170   170   565.705882
# 9             Eger   47.9025    20.3772       53696    92   583.652174
# 10        Veszprém   47.0928    17.9093       58763   126   466.373016
# 11       Tatabánya   47.5883    18.3973       66124    91   726.637363
# 12     Salgótarján   48.1042    19.8033       32133   102   315.029412
# 13        Kaposvár   46.3597    17.7952       60300   113   533.628319

# %%
sorted_df = df.sort_values(by=["population","area"], ascending=[False,True])

print(sorted_df)
# Out:
#               city  latitude  longitude  population  area  pop_density
# 0         Budapest   47.4979    19.0402     1752286   525  3337.687619
# 1         Debrecen   47.5316    21.6273      202402   461   439.049892
# 2           Szeged   46.2530    20.1414      160766   280   574.164286
# 5          Miskolc   48.1031    20.7784      151025   236   639.936441
# 3             Pécs   46.0727    18.2323      145347   162   897.203704
# 4             Győr   47.6875    17.6504      131267   174   754.408046
# 6      Nyíregyháza   47.9495    21.7247      119746   274   437.029197
# 7        Kecskemét   46.8964    19.6897      110687   321   344.819315
# 8   Székesfehérvár   47.1860    18.4221       96170   170   565.705882
# 11       Tatabánya   47.5883    18.3973       66124    91   726.637363
# 13        Kaposvár   46.3597    17.7952       60300   113   533.628319
# 10        Veszprém   47.0928    17.9093       58763   126   466.373016
# 9             Eger   47.9025    20.3772       53696    92   583.652174
# 12     Salgótarján   48.1042    19.8033       32133   102   315.029412

# %%
filtered_df = df[(df["population"] > 100000) & (df["pop_density"] < 500)]
print(filtered_df[["city","pop_density"]])
# Out:
#           city  pop_density
# 1     Debrecen   439.049892
# 6  Nyíregyháza   437.029197
# 7    Kecskemét   344.819315

# %%
labels = ["Kisváros", "Közepes város", "Nagyváros"]
df["city_category"] = pd.cut(df["population"], bins=[0, 100000, 150000,np.inf], labels=labels)

print(df[["city","population","city_category"]])
# Out:
#               city  population  city_category
# 0         Budapest     1752286      Nagyváros
# 1         Debrecen      202402      Nagyváros
# 2           Szeged      160766      Nagyváros
# 3             Pécs      145347  Közepes város
# 4             Győr      131267  Közepes város
# 5          Miskolc      151025      Nagyváros
# 6      Nyíregyháza      119746  Közepes város
# 7        Kecskemét      110687  Közepes város
# 8   Székesfehérvár       96170       Kisváros
# 9             Eger       53696       Kisváros
# 10        Veszprém       58763       Kisváros
# 11       Tatabánya       66124       Kisváros
# 12     Salgótarján       32133       Kisváros
# 13        Kaposvár       60300       Kisváros

# %%
grouped = df.groupby("city_category").agg({'population':'mean', 'pop_density':'mean'})

print(grouped)
# Out:
#                   population  pop_density
# city_category
# Kisváros        61197.666667   531.837694
# Közepes város  126761.750000   608.365065
# Nagyváros      566619.750000  1247.709559
# C:\Users\senya\AppData\Local\Temp\ipykernel_15600\655464953.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby("city_category").agg({'population':'mean', 'pop_density':'mean'})

# %%
df.to_csv("processed_citites.csv", index=False)
